# %%
import pandas as pd 
import sqlite3

# %%
files = pd.read_csv('/home/jack/projects/RiboSeqOrg-DataPortal/data/trips_files.csv')
studies = pd.read_csv('/home/jack/projects/RiboSeqOrg-DataPortal/data/trips_studies.csv')

# %%
files.head()
# Out:
#    Unnamed: 0  0   1  2                 3                             4
# 0           0  1  10  1  SRR1945002.shelf               N2_L4_ribo_rep1  \
# 1           1  2  10  1  SRR1945003.shelf               N2_L4_ribo_rep2
# 2           2  3  10  1  SRR1945004.shelf            tut_1_L4_ribo_rep1
# 3           3  4  10  1  SRR1945005.shelf            tut_1_L4_ribo_rep2
# 4           4  5  10  1  SRR1945008.shelf  tut_1_elpc_1_adult_mRNA_rep1
#
#          5  6           7   8    9
# 0  riboseq  1  19142565.0 NaN  NaN
# 1  riboseq  1   2510719.0 NaN  NaN
# 2  riboseq  1  13790426.0 NaN  NaN
# 3  riboseq  1   2718916.0 NaN  NaN
# 4   rnaseq  1  24901945.0 NaN  NaN

# %%
studies.head()
# Out:
#    Unnamed: 0  0   1                2
# 0           0 -1   0              NaN  \
# 1           1  1  10     Nedialkova15
# 2           2  2   7           Dunn13
# 3           3  3   8    Nakahigashi16
# 4           4  4   8  Woolstenhulme15
#
#                                                    3          4     5
# 0                                                NaN        NaN   NaN  \
# 1                           Nedialkova DD, Leidel SA  SRP056647  2015
# 2  Dunn JG, Foo CK, Belletier NG, Gavis ER, Weiss...  SRP028243  2013
# 3  Nakahigashi K, Takai Y, Kimura M, Abe N, Nakay...  DRP003075  2016
# 4  Woolstenhulme CJ, Guydosh NR, Green R, Buskirk AR  SRP051520  2015
#
#           6                                                  7              8
# 0       NaN                                                NaN            NaN  \
# 1  26052047  "https://linkinghub.elsevier.com/retrieve/pii/...       GSE67387
# 2  24302569              "https://doi.org/10.7554/eLife.01179"       GSE49197
# 3       NaN  https://academic.oup.com/dnaresearch/article-l...  Nakahigashi16
# 4  25843707  "https://linkinghub.elsevier.com/retrieve/pii/...       GSE64488
#
#                    9                                                 10
# 0                NaN                                                NaN  \
# 1                NaN  Optimization of Codon Translation Rates via tR...
# 2  CTGTAGGCACCATCAAT  Ribosome profiling reveals pervasive and regul...
# 3                NaN  Comprehensive identification of translation st...
# 4  CTGTAGGCACCATCAAT  High-precision analysis of translational pausi...
#
#                                                   11  12  13
# 0                                                NaN   0   0
# 1  Ribosome profiling of wild-type and tRNA modif...   0   1
# 2  12 samples of Drosophila ribosome profiling an...   0   1
# 3                                                NaN   0   1
# 4  Ribosome profiling of E. coli MG1655 and mutan...   0   1
